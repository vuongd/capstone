# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### Part 1

# %% [markdown]
# Load required libraries for this task

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
import requests

# %% [markdown]
# Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe like the one shown below:

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text

# %% [markdown]
# Let's define now some helper functions to automatize the extract of html elements

# %%
def find_all(text, sub):
    """ find all occurences of substring in larger string 
    and return their indices relative to the text string
    
    Key arguments
    -------------
    text:      text string
    sub:       substring to be found in text
    
    Return
    -------
    indices:   indices of the found occurences relative to text
    """
    occurencesIndex = []
    index = 0
    while index < len(text):
        index = text.find(sub, index)
        if index == -1:
            return occurencesIndex
        else:
            occurencesIndex.append(index)
            index += 1 
    return occurencesIndex

def getValue(text, b_element, e_element):
    """ get text snippet with given indices for beginning and ending
    Key arguments:
    -------------
    text:       text string
    b_element:  begin html element <element>
    e_element:  end html element </element>
    
    return:
    ------
    text snippet if element found in text, otherwise return original text
    """
    if text.find(b_element) != -1:
        return text[text.find(b_element) + len(b_element):text.find(e_element)]
    else:
        return text

# %% [markdown]
# The following function extracts the data from the table of the wikipedia homepage

# %%
def getData(text):
    """ get Data from html code
    Key argument:
    ------------
    text:      text from which the data will be extracted (table text)
    
    return:
    -------
    pd.Dataframe 
    """
    rows = zip(find_all(text, "<tr>")[1:], find_all(text, "</tr>")[1:])
    data =  []
    for row_b, row_e in rows:
        row_data = text[row_b:row_e]
        sub_indices = zip(find_all(row_data, "<td>"), find_all(row_data, "</td>"))
        data.append([row_data[sub_b+4:sub_e] for sub_b, sub_e in sub_indices])
    return pd.DataFrame(data, columns = ['PostalCode' , 'Borough', 'Neighborhood'])

# %% [markdown]
# table html from the page

# %%
tabledata = page[page.find('<table class="wikitable sortable">') + len('<table class="wikitable sortable">'):page.find('<table class="multicol" role="presentation" style="border-collapse: collapse; padding: 0; border: 0; background:transparent; width:100%;">')]

# %% [markdown]
# get the data frame of the table html

# %%
postcode_can = getData(tabledata)

# %% [markdown]
# some decoration since Borough and Neighborhood have data elements of type hyperlink

# %%
postcode_can["Borough"] = [getValue(iString, '">', "</a>") for iString in postcode_can["Borough"]]
postcode_can["Neighborhood"] = [getValue(iString, '">', "</a>").replace("\n", "") for iString in postcode_can["Neighborhood"]]

# %% [markdown]
# Only process the cells that have an assigned Borough. Ignore cells with a borough that is Not assigned.

# %%
postcode_can = postcode_can[postcode_can["Borough"] != "Not assigned"]

# %% [markdown]
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma.

# %%
postcode_can['Neighborhood'] = postcode_can.groupby(['PostalCode'])['Neighborhood'].transform(lambda x: ', '.join(x))
postcode_can = postcode_can[['PostalCode', "Borough", "Neighborhood"]].drop_duplicates()
postcode_can.head(10)
# Out:
#    PostalCode           Borough                      Neighborhood
# 2         M3A        North York                         Parkwoods
# 3         M4A        North York                  Victoria Village
# 4         M5A  Downtown Toronto         Harbourfront, Regent Park
# 6         M6A        North York  Lawrence Heights, Lawrence Manor
# 8         M7A      Queen's Park                      Not assigned
# 10        M9A         Etobicoke                  Islington Avenue
# 11        M1B       Scarborough                    Rouge, Malvern
# 14        M3B        North York                   Don Mills North
# 15        M4B         East York   Woodbine Gardens, Parkview Hill
# 17        M5B  Downtown Toronto          Ryerson, Garden District

# %% [markdown]
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
postcode_can.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Part 2

# %% [markdown]
# Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.

# %%
def getGeomSpatialData():
    data = pd.read_csv("Geospatial_Coordinates.csv")
    return data

# %%
geomspatial = getGeomSpatialData()
geomspatial.set_index("Postal Code", inplace = True)
postcode_can.set_index("PostalCode", inplace = True)#_valiues(["PostalCode"])#[postcode_can["PostalCode"] == geomspatial["Postal Code"]]
postcode_can.join(geomspatial)
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 6          M6A        North York
# 8          M7A      Queen's Park
# 10         M9A         Etobicoke
# 11         M1B       Scarborough
# 14         M3B        North York
# 15         M4B         East York
# 17         M5B  Downtown Toronto
# 19         M6B        North York
# 22         M9B         Etobicoke
# 27         M1C       Scarborough
# 31         M3C        North York
# 33         M4C         East York
# 34         M5C  Downtown Toronto
# 35         M6C              York
# 38         M9C         Etobicoke
# 42         M1E       Scarborough
# 47         M4E      East Toronto
# 48         M5E  Downtown Toronto
# 49         M6E              York
# 53         M1G       Scarborough
# 56         M4G         East York
# 57         M5G  Downtown Toronto
# 58         M6G  Downtown Toronto
# 62         M1H       Scarborough
# 63         M2H        North York
# 64         M3H        North York
# 67         M4H         East York
# ..         ...               ...
# 168        M4R   Central Toronto
# 169        M5R   Central Toronto
# 172        M6R      West Toronto
# 174        M7R       Mississauga
# 176        M9R         Etobicoke
# 180        M1S       Scarborough
# 183        M4S   Central Toronto
# 184        M5S  Downtown Toronto
# 186        M6S      West Toronto
# 191        M1T       Scarborough
# 196        M4T   Central Toronto
# 198        M5T  Downtown Toronto
# 205        M1V       Scarborough
# 211        M4V   Central Toronto
# 216        M5V  Downtown Toronto
# 225        M8V         Etobicoke
# 228        M9V         Etobicoke
# 236        M1W       Scarborough
# 239        M4W  Downtown Toronto
# 240        M5W  Downtown Toronto
# 243        M8W         Etobicoke
# 245        M9W         Etobicoke
# 246        M1X       Scarborough
# 249        M4X  Downtown Toronto
# 251        M5X  Downtown Toronto
# 255        M8X         Etobicoke
# 262        M4Y  Downtown Toronto
# 265        M7Y      East Toronto
# 266        M8Y         Etobicoke
# 282        M8Z         Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 2                                            Parkwoods         M1E  43.763573
# 3                                     Victoria Village         M1G  43.770992
# 4                            Harbourfront, Regent Park         M1H  43.773136
# 6                     Lawrence Heights, Lawrence Manor         M1K  43.727929
# 8                                         Not assigned         M1M  43.716316
# 10                                    Islington Avenue         M1P  43.757410
# 11                                      Rouge, Malvern         M1R  43.750072
# 14                                     Don Mills North         M1V  43.815252
# 15                     Woodbine Gardens, Parkview Hill         M1W  43.799525
# 17                            Ryerson, Garden District         M2H  43.803762
# 19                                           Glencairn         M2K  43.786947
# 22   Cloverdale, Islington, Martin Grove, Princess ...         M2N  43.770120
# 27              Highland Creek, Rouge Hill, Port Union         M3C  43.725900
# 31                    Flemingdon Park, Don Mills South         M3L  43.739015
# 33                                    Woodbine Heights         M3N  43.761631
# 34                                      St. James Town         M4A  43.725882
# 35                                  Humewood-Cedarvale         M4B  43.706397
# 38   Bloordale Gardens, Eringate, Markland Wood, Ol...         M4G  43.709060
# 42                   Guildwood, Morningside, West Hill         M4L  43.668999
# 47                                         The Beaches         M4S  43.704324
# 48                                         Berczy Park         M4T  43.689574
# 49                                 Caledonia-Fairbanks         M4V  43.686412
# 53                                              Woburn         M5A  43.654260
# 56                                             Leaside         M5E  43.644771
# 57                                  Central Bay Street         M5G  43.657952
# 58                                            Christie         M5H  43.650571
# 62                                           Cedarbrae         M5M  43.733283
# 63                                   Hillcrest Village         M5N  43.711695
# 64     Bathurst Manor, Downsview North, Wilson Heights         M5P  43.696948
# 67                                    Thorncliffe Park         M5T  43.653206
# ..                                                 ...         ...        ...
# 168                                 North Toronto West         NaN        NaN
# 169                The Annex, North Midtown, Yorkville         NaN        NaN
# 172                             Parkdale, Roncesvalles         NaN        NaN
# 174              Canada Post Gateway Processing Centre         NaN        NaN
# 176  Kingsview Village, Martin Grove Gardens, Richv...         NaN        NaN
# 180                                          Agincourt         NaN        NaN
# 183                                         Davisville         NaN        NaN
# 184                     Harbord, University of Toronto         NaN        NaN
# 186                                 Runnymede, Swansea         NaN        NaN
# 191            Clarks Corners, Sullivan, Tam O'Shanter         NaN        NaN
# 196                        Moore Park, Summerhill East         NaN        NaN
# 198          Chinatown, Grange Park, Kensington Market         NaN        NaN
# 205  Agincourt North, L'Amoreaux East, Milliken, St...         NaN        NaN
# 211  Deer Park, Forest Hill SE, Rathnelly, South Hi...         NaN        NaN
# 216  CN Tower, Bathurst Quay, Island airport, Harbo...         NaN        NaN
# 225       Humber Bay Shores, Mimico South, New Toronto         NaN        NaN
# 228  Albion Gardens, Beaumond Heights, Humbergate, ...         NaN        NaN
# 236                                    L'Amoreaux West         NaN        NaN
# 239                                           Rosedale         NaN        NaN
# 240                    Stn A PO Boxes 25 The Esplanade         NaN        NaN
# 243                             Alderwood, Long Branch         NaN        NaN
# 245                                          Northwest         NaN        NaN
# 246                                        Upper Rouge         NaN        NaN
# 249                        Cabbagetown, St. James Town         NaN        NaN
# 251             First Canadian Place, Underground city         NaN        NaN
# 255      The Kingsway, Montgomery Road, Old Mill North         NaN        NaN
# 262                               Church and Wellesley         NaN        NaN
# 265  Business Reply Mail Processing Centre 969 Eastern         NaN        NaN
# 266  Humber Bay, King's Mill Park, Kingsway Park So...         NaN        NaN
# 282  Kingsway Park South West, Mimico NW, The Queen...         NaN        NaN
#
#      Longitude
# 2   -79.188711
# 3   -79.216917
# 4   -79.239476
# 6   -79.262029
# 8   -79.239476
# 10  -79.273304
# 11  -79.295849
# 14  -79.284577
# 15  -79.318389
# 17  -79.363452
# 19  -79.385975
# 22  -79.408493
# 27  -79.340923
# 31  -79.506944
# 33  -79.520999
# 34  -79.315572
# 35  -79.309937
# 38  -79.363452
# 42  -79.315572
# 47  -79.388790
# 48  -79.383160
# 49  -79.400049
# 53  -79.360636
# 56  -79.373306
# 57  -79.387383
# 58  -79.384568
# 62  -79.419750
# 63  -79.416936
# 64  -79.411307
# 67  -79.400049
# ..         ...
# 168        NaN
# 169        NaN
# 172        NaN
# 174        NaN
# 176        NaN
# 180        NaN
# 183        NaN
# 184        NaN
# 186        NaN
# 191        NaN
# 196        NaN
# 198        NaN
# 205        NaN
# 211        NaN
# 216        NaN
# 225        NaN
# 228        NaN
# 236        NaN
# 239        NaN
# 240        NaN
# 243        NaN
# 245        NaN
# 246        NaN
# 249        NaN
# 251        NaN
# 255        NaN
# 262        NaN
# 265        NaN
# 266        NaN
# 282        NaN
#
# [103 rows x 6 columns]
